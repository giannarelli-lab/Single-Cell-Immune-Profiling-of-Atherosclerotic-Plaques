# %%
import papermill as pm

# %%
# !mkdir ../papermill_notebooks/
template_notebook = '1.0_CITE-seq_ADT_PBMC_and_Plaque.ipynb'
tmp = pm.execute_notebook(
    template_notebook,
    '../papermill_notebooks/' + template_notebook

)
# Out:
# mkdir: ../papermill_notebooks/: File exists
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=11.0, style=ProgressStyle(description_wid…

# %%
# !mkdir ../reports/

# !jupyter nbconvert --to html --output-dir=../reports/ ../papermill_notebooks/*.ipynb
# Out:
# mkdir: ../reports/: File exists
# [NbConvertApp] Converting notebook ../papermill_notebooks/1.0_CITE-seq_ADT_PBMC_and_Plaque.ipynb to html
# [NbConvertApp] Writing 7855148 bytes to ../reports/1.0_CITE-seq_ADT_PBMC_and_Plaque.html
