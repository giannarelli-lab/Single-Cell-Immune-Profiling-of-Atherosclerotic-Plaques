# %% [markdown]
# # 1.5 CITE-seq GEX Plaque Macrophages
# This notebook displays interactive heatmaps of single cell gene expression data from plaque Macrophages. The data has been UMI normalized and Z-scored - please see manuscript for additional information.

# %%
from clustergrammer2 import net
import helper_functions as hf
df = {}
# Out:
# >> clustergrammer2 backend version 0.5.1

# %%
net.load_file('../data/citeseq_gex_plaque_macrophages.txt')
df['gex'] = net.export_df()
df['gex'].shape
# Out:
# (100, 265)

# %%
cat_colors = net.load_json_to_dict('../data/cluster-colors.json')
net.set_cat_colors(axis='col', cat_index=2, cat_title='Cluster', cat_colors=cat_colors)

# %% [markdown]
# # Plaque Gene Expression Macrophages
# 265 Macrophages from a plaque are hierarchically clustered based on the top 100 genes based on variance.

# %%
net.load_df(df['gex'])
net.widget()
# Out:
# ExampleWidget(network='{"row_nodes": [{"name": "MALAT1", "ini": 100, "clust": 10, "rank": 39, "rankvar": 43, "…

# %% [markdown]
# # UMAP Macrophages
# Macrophages from a plaque are visualized using the dimensionality reduction technique, UMAP, using the same dataset as above.

# %%
hf.make_umap_plot(df['gex'], 2, cat_colors, 'Macrophages', s=50, alpha=1)
